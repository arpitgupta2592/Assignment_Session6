# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt;

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv')

# %%
count=titanic['sex'].value_counts()

# %%
count
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
ax=plt.subplot()
plt.pie(count.values.tolist(),labels=count.index.values.tolist())
ax.set_title('Male/Female proportion')
# Out:
# Text(0.5, 1.0, 'Male/Female proportion')

# %%
titanic.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
titanic.fare.fillna(method='ffill', inplace=True)

# %%
titanic.sex.fillna(method='ffill', inplace=True)

# %%
titanic.age.fillna(method='ffill', inplace=True)

# %%
titanic.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             0
# age             0
# sibsp           1
# parch           1
# ticket          1
# fare            0
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
plt.scatter(titanic.age,titanic.fare,c=pd.factorize(titanic['sex'])[0], alpha=0.5)
